# %%
import pandas as pd
#读取data/test_data.xlsx
df = pd.read_excel('data/test_data.xlsx')
#打印df
print(df)
#打印df的列名
print(df.columns)
# Out:
#       C_ACTUAL_T_ODS_L611_TPSCRA2  SI_ACTUAL_T_ODS_L611_TPSCRA2  \
# 0                          0.0010                         0.001
# 1                          0.0820                         0.250
# 2                          0.0460                         0.001
# 3                          0.0440                         0.012
# 4                          0.0730                         0.200
# ...                           ...                           ...
# 4442                       0.0013                         0.000
# 4443                       0.0012                         0.001
# 4444                       0.0590                         0.073
# 4445                       0.0570                         0.071
# 4446                       0.0013                         0.003
#
#       MN_ACTUAL_T_ODS_L611_TPSCRA2  P_ACTUAL_T_ODS_L611_TPSCRA2  \
# 0                             0.08                        0.006
# 1                             1.91                        0.009
# ...
